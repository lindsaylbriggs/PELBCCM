# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_directory = 'drive/MyDrive/CCM/Test_Datasets/'
# Out:
# 45

# %%
data = []
for file in os.listdir(image_directory):
  if file.endswith('.png'):
    imgpath = os.path.join(image_directory, file)
    img = Image.open(imgpath)
    img = img.resize((128, 128))
    img_array = np.array(img)
    data.append({'name': imgpath, 'Image': img_array, 'label': None})
  else:
    pass

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                   name  \
# 0    drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 1    drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 2    drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 3    drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 4    drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# ..                                                 ...
# 469  drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 470  drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 471  drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 472  drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
# 473  drive/MyDrive/CCM/Test_Extracted_Cloud_Feature...
#
#                                                  Image label
# 0    [[[254, 247, 254, 255], [254, 247, 254, 255], ...  None
# 1    [[[254, 247, 254, 255], [254, 247, 254, 255], ...  None
# 2    [[[254, 247, 254, 255], [254, 247, 254, 255], ...  None
# ...

# %%
df.to_pickle('test_image_list.pkl')
# !cp test_image_list.pkl drive/MyDrive/CCM/
